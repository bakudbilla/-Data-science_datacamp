# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle as pkl
with open("avoplotto.pkl", 'rb') as f:
    avodf = pkl.load(f)

# %%
avodf
# Out:
#             date          type  year  avg_price         size     nb_sold
# 0     2015-12-27  conventional  2015       0.95        small  9626901.09
# 1     2015-12-20  conventional  2015       0.98        small  8710021.76
# 2     2015-12-13  conventional  2015       0.93        small  9855053.66
# 3     2015-12-06  conventional  2015       0.89        small  9405464.36
# 4     2015-11-29  conventional  2015       0.99        small  8094803.56
# ...          ...           ...   ...        ...          ...         ...
# 1009  2018-02-04       organic  2018       1.53  extra_large     1703.52
# 1010  2018-01-28       organic  2018       1.61  extra_large     1270.61
# 1011  2018-01-21       organic  2018       1.63  extra_large     1490.02
# 1012  2018-01-14       organic  2018       1.59  extra_large     1580.01
# 1013  2018-01-07       organic  2018       1.51  extra_large     1289.07
#
# [1014 rows x 6 columns]

# %%
avodf["avg_price"].hist(bins=5)
# Out:
# <Axes: >

# %%
avg_price_by_type=avodf.groupby("type")["avg_price"].mean()
avg_price_by_type
# Out:
# type
# conventional    1.092012
# organic         1.546036
# Name: avg_price, dtype: float64

# %%
avg_price_by_type.plot(kind="bar", rot=360, title="Mean price by avocado type")
# Out:
# <Axes: title={'center': 'Mean price by avocado type'}, xlabel='type'>

# %%
avodf.plot(x='date', y="avg_price", kind="line")
# Out:
# <Axes: xlabel='date'>

# %%
avodf[avodf["type"]=="conventional"]["avg_price"].hist(alpha=0.7)
avodf[avodf["type"]=="organic"]["avg_price"].hist(alpha=0.7)
plt.legend(["C","O"])

# %%
avodf.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
avodf.plot(x="avg_price",y="nb_sold",kind="scatter")
# Out:
# <Axes: xlabel='avg_price', ylabel='nb_sold'>

# %%
nb_sold_by_size =avodf.groupby("size")["nb_sold"].sum()

# %%
nb_sold_by_size
# Out:
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %%
avocados.plot(kind="bar", rot=360, title="number of avocados sold by size")

# %% [markdown]
# # Joining Data with pandas

# %%
 Print variance and sd of co2_emission for each food_category
print(food_consumption['co2_emission'].groupby(food_consumption['food_category']).agg([np.std, np.var]))
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Create histogram of co2_emission for food_category 'beef'
plt.hist(food_consumption[food_consumption["food_category"]=="beef"]["co2_emission"], bins=5)
# Show plot
plt.show()

# Create histogram of co2_emission for food_category 'eggs'
plt.hist(food_consumption[food_consumption["food_category"]=="beef"]["co2_emission"], bins=5)
# Show plot
plt.show()
