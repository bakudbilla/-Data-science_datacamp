# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
divorce=pd.read_csv("divorce (1).csv",parse_dates=["marriage_date"])
divorce.head()
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN

# %%
divorce.dtypes
# Out:
# divorce_date                 object
# dob_man                      object
# education_man                object
# income_man                  float64
# dob_woman                    object
# education_woman              object
# income_woman                float64
# marriage_date        datetime64[ns]
# marriage_duration           float64
# num_kids                    float64
# dtype: object

# %%
#you can also change dat to Date time after loading the normal way 
#using pd.to_datetime
divorce["marriage_date"]=pd.to_datetime(divorce["marriage_date"])
divorce.dtypes
# Out:
# divorce_date                 object
# dob_man                      object
# education_man                object
# income_man                  float64
# dob_woman                    object
# education_woman              object
# income_woman                float64
# marriage_date        datetime64[ns]
# marriage_duration           float64
# num_kids                    float64
# dtype: object

# %%
divorce.head(5)
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN

# %% [markdown]
# #Assuming I have columns month,day and year,
# #it can be combined to form a date
# divorce["marriage_date"]=pd.to_datetime(divorce[["month","day","year"]])

# %%
#Extracting month,day ans year from a datetime column
divorce["marriage_month"]=divorce["marriage_date"].dt.month
divorce.head()
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids  \
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN
#
#    marriage_month
# 0               6
# 1               9
# 2               2
# 3               5
# 4               8

# %%
divorce["marriage_year"]=divorce["marriage_date"].dt.year
divorce.head()
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids  \
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN
#
#    marriage_month  marriage_year
# 0               6           2000
# 1               9           2001
# ...

# %%
#Visualizing patterns over time
sns.lineplot(data=divorce,x="marriage_month",y="marriage_duration")
# Out:
# <Axes: xlabel='marriage_month', ylabel='marriage_duration'>

# %% [markdown]
# # Correlation

# %% [markdown]
# #it can help use variables to oredict future outcomes

# %%
divorce.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10668\3332814392.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   divorce.corr()
#                    income_man  income_woman  marriage_duration  num_kids  \
# income_man           1.000000      0.318047           0.085321  0.040848
# income_woman         0.318047      1.000000           0.078677 -0.018015
# marriage_duration    0.085321      0.078677           1.000000  0.447358
# num_kids             0.040848     -0.018015           0.447358  1.000000
# marriage_month       0.013652      0.041441           0.001433 -0.000551
# marriage_year        0.019170      0.026433          -0.812469 -0.461495
#
#                    marriage_month  marriage_year
# income_man               0.013652       0.019170
# income_woman             0.041441       0.026433
# ...

# %% [markdown]
# Negative correlation=> As one value increases,the other decreases
# Values closer to 0 => weak relationship
# values closer to 1 or -1  => strong relationship

# %% [markdown]
# .corr() claculates Pearson correlation coefficient, measuring linear relatioship

# %% [markdown]
# # correlation heatmaps

# %%
sns.heatmap(divorce.corr(),annot=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10668\1848111086.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(divorce.corr(),annot=True)
# <Axes: >

# %%
#correlation in context
divorce["divorce_date"].min()
# Out:
# '2000-01-08'

# %%
divorce["divorce_date"].max()
# Out:
# '2015-11-03'

# %%
sns.scatterplot(data=divorce, x="income_man",y="income_woman")
# Out:
# <Axes: xlabel='income_man', ylabel='income_woman'>

# %%
sns.pairplot(data=divorce)

# %% [markdown]
# #Data might have a strong relationship but not linear

# %% [markdown]
# Research more on pairplots

# %%
# translating the pairplot I creating above can be very daunting 
#Going through all those charts can be difficult, so I can decide to lower them
sns.pairplot(data=divorce, vars=["income_man","income_woman","marriage_duration"])

# %%
sns.scatterplot(data=divorce,x="marriage_duration",y="marriage_month")
# Out:
# <Axes: xlabel='marriage_duration', ylabel='marriage_month'>

# %% [markdown]
# # Factor relationship and distributions

# %%
divorce["education_man"].value_counts()
# Out:
# Professional    1313
# Preparatory      501
# Secondary        288
# Primary          100
# None               4
# Other              3
# Name: education_man, dtype: int64

# %%
#Exploring categorical relationships
sns.histplot(data=divorce,x="marriage_duration",hue="education_man",binwidth=1)
# Out:
# <Axes: xlabel='marriage_duration', ylabel='Count'>

# %%
#kernel Density Estimate(KDE)plots
sns.kdeplot(data=divorce,x="marriage_duration",hue="education_man",cut=0)
# Out:
# <Axes: xlabel='marriage_duration', ylabel='Density'>

# %%
#cummulative KDE plots
sns.kdeplot(data=divorce,x="marriage_duration",hue="education_man",cut=0,cumulative=True)
plt.show()

# %%
divorce["dob_man"]=pd.to_datetime(divorce["dob_man"])
divorce["dob_woman"]=pd.to_datetime(divorce["dob_woman"])

# %%
#Relatioship between marriage age and education 
divorce["man_age_marriage"]=divorce["marriage_year"]-divorce["dob_man"].dt.year
divorce["woman_age_marriage"]=divorce["marriage_year"]-divorce["dob_woman"].dt.year

# %%
sns.scatterplot(data=divorce,x="woman_age_marriage",y="man_age_marriage",hue="education_man")
# Out:
# <Axes: xlabel='woman_age_marriage', ylabel='man_age_marriage'>
