# %% [markdown]
# # Matplolib

# %%
import matplotlib.pyplot as plt

# %%
year = [1950,1970,1990,2018]
pop = [2.519, 3.263,5.263, 6.972]

# %%
plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year,pop)

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
#     number of values in each bin, then draws the distribution either as a
#     `.BarContainer` or `.Polygon`. The *bins*, *range*, *density*, and
#     *weights* parameters are forwarded to `numpy.histogram`.
#
#     If the data has already been binned and counted, use `~.bar` or
#     `~.stairs` to plot the distribution::
#
#         counts, bins = np.histogram(x)
#         plt.stairs(counts, bins)
#
#     Alternatively, plot pre-computed bins and counts using ``hist()`` by
#     treating each bin as a single point with a weight equal to its count::
#
# ...

# %%
values=[0,0.6,1.4,1.6,2,2.4,2.5,2.6,3.2,3.5]
plt.hist(values, bins=3)
plt.show()

# %%
#customizing my line chat

# %%
#adding more data
year =[1800, 1850,1900] + year
pop=[1.0,1.576,1.389] + pop
plt.plot(year, pop)
plt.title("Population Growth per year")
plt.yticks([0, 2,4,6,8],
          ['0B','2B','3B','4B','5B'])
plt.show()

# %% [markdown]
# # Dictionaries

# %%
pop= [3.55,2.77,39.21]
countries=["afghanistan", "albania", "algeria"]

# %%
dict= {"afghanistan":30.55,"albania":2.77,"algeria":39.22}

# %%
dict
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.22}

# %%
dict["albania"]
# Out:
# 2.77

# %%
#adding data to a dictionary

# %%
dict["sealand"]=45.5

# %%
dict
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.22, 'sealand': 45.5}

# %%
dict["sealand"]=45.6

# %%
dict
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.22, 'sealand': 45.6}

# %%
#todelete
del(dict["sealand"])

# %%
dict
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.22}

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
seattle_weather=pd.read_csv("seattle_weather.csv")
austin_weather=pd.read_csv("austin_weather.csv")

# %%
seattle_weather.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# ...

# %%
seattle_weather["DATE"]
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 199     8
# 200     9
# 201    10
# 202    11
# 203    12
# Name: DATE, Length: 204, dtype: int64

# %%
def map_month_name(date):
    month_names = [
        'Jan', 'Feb', 'Mar', 'Apr',
        'May', 'Jun', 'Jul', 'Aug',
        'Sep', 'Oct', 'Nov', 'Dec'
    ]
    return month_names[date - 1]

# Apply the function to create a new column with month names
seattle_weather['Month'] = seattle_weather['DATE'].apply(map_month_name)
austin_weather['Month'] = austin_weather['DATE'].apply(map_month_name)

# %%
seattle_weather.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  \
# ...

# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
ax.plot(seattle_weather["Month"], seattle_weather["MLY-PRCP-NORMAL"])
#ax.plot(seattle_weather["Month"], seattle_weather["MLY-PRCP-NORMAL"])

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
#ax.plot(austin_weather["Month"], austin_weather["MLY-PRCP-NORMAL"])

# Call the show function

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
climate_change=pd.read_csv("climate_change.csv",parse_dates=["date"],index_col="date")

# %%
climate_change.index
# Out:
# DatetimeIndex(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06',
#                '1958-07-06', '1958-08-06', '1958-09-06', '1958-10-06',
#                '1958-11-06', '1958-12-06',
#                ...
#                '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06',
#                '2016-07-06', '2016-08-06', '2016-09-06', '2016-10-06',
#                '2016-11-06', '2016-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)

# %%
climate_change["relative_temp"]
# Out:
# date
# 1958-03-06    0.10
# 1958-04-06    0.01
# 1958-05-06    0.08
# 1958-06-06   -0.05
# 1958-07-06    0.06
#               ...
# 2016-08-06    0.98
# 2016-09-06    0.87
# 2016-10-06    0.89
# 2016-11-06    0.93
# 2016-12-06    0.81
# Name: relative_temp, Length: 706, dtype: float64

# %%
climate_change["co2"]
# Out:
# date
# 1958-03-06    315.71
# 1958-04-06    317.45
# 1958-05-06    317.50
# 1958-06-06       NaN
# 1958-07-06    315.86
#                ...
# 2016-08-06    402.27
# 2016-09-06    401.05
# 2016-10-06    401.59
# 2016-11-06    403.55
# 2016-12-06    404.45
# Name: co2, Length: 706, dtype: float64

# %%
fig, ax=plt.subplots()
ax.plot(climate_change.index,climate_change["co2"])
ax.set_xlabel('Time')
ax.set_ylabel("CO2(ppm)")
plt.show()

# %%
sixties=climate_change["1960-01-10":"1969-12-31"]
fig, ax=plt.subplots()
ax.plot(sixties.index,sixties["co2"])
ax.set_xlabel('Time')
ax.set_ylabel("CO2(ppm)")
plt.show()

# %%
climate_change.index
# Out:
# DatetimeIndex(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06',
#                '1958-07-06', '1958-08-06', '1958-09-06', '1958-10-06',
#                '1958-11-06', '1958-12-06',
#                ...
#                '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06',
#                '2016-07-06', '2016-08-06', '2016-09-06', '2016-10-06',
#                '2016-11-06', '2016-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)

# %%
sixties=climate_change["1960-01-10":"1969-12-31"]
fig, ax=plt.subplots()
ax.plot(sixties.index,sixties["co2"])
ax.set_xlabel('Time')
ax.set_ylabel("CO2(ppm)")
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(climate_change.index,climate_change["co2"])
ax.set_xlabel('Time')
ax.set_ylabel("CO2(ppm)", color="blue")
ax.tick_params("y",colors="blue")
ax2=ax.twinx()
ax2.plot(climate_change.index,climate_change["relative_temp"],color="red")
ax2.set_ylabel("Relative temperature(celcius)")
ax2.tick_params("y",colors="red")
plt.show()

# %%
#funtion that plots time-series
def plot_timeseries(axes,x,y,color,xlabel,ylabel):
    axes.plot(x,y,color=color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel,color=color)
    axes.tick_params("y",colors=color)

# %%
#to plot:
fig, ax=plt.subplots()
plot_timeseries(ax,climate_change.index,climate_change['co2'],
                'blue','Time','Co2(ppm)')
ax2=ax.twinx()
plot_timeseries(ax2,climate_change.index,climate_change['relative_temp'],
                'red','Time','Relative temperature(Celcius)')
plt.show()
